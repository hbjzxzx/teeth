# %%
import matplotlib.pyplot as plt
import numpy as np
import SimpleITK as sitk
from utils import *
from config import config

# %%
datacfg = config('configs/dataconfig.yaml')

# %%
index = 16
fileName = getFileNames(index, datacfg, 'file')
oseedName = getFileNames(index, datacfg, 'tseed')
seedName = getFileNames(index, datacfg, 'seed')

# %%
images = readFromNii(str(fileName))

# %%
oseeds = readFromNii(str(oseedName))
seeds = readFromNii((str(seedName)))

# %%
plt.imshow(images[142], cmap='gray')

# %%
imageLargeCrack = images[151]

# %%
imageSmallCrack = images[142]

# %%
limage= resizeImage(normalImage(imageLargeCrack,8), 267, 374)

# %%
imageSmallCrack.shape
# Out:
# (374, 267)

# %%
plt.imshow(limage, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.savefig('largeCrack.png')

# %%
plt.imshow(imageSmallCrack, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.savefig('smallCrack.png')

# %%
imageIndex = 120

# %%
red = np.zeros_like(oseeds)

# %%
c = np.where(oseeds[imageIndex], , (0,0,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-be8938aac529> in <module>
# ----> 1 c = np.where(oseeds[imageIndex], (255,0,0), (0,0,0))
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (427,342) (3,) (3,)

# %%
plt.imshow(images[imageIndex], cmap='gray')
plt.imshow(oseeds[imageIndex], alpha=0.4)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.imshow(oseeds[imageIndex], cmap='gray')
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.imshow(seeds[imageIndex], cmap='gray')
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
